# %%
import random, pygame, sys, os
import math
from pygame.locals import *
from pygame import gfxdraw

pygame.init()
L, H = 900, 600
CX, CY = int(L/2), int(H/2)
DISPLAYSURF = pygame.display.set_mode((L, H))
FPSCLOCK = pygame.time.Clock()
BASICFONT = pygame.font.Font('freesansbold.ttf',18)

position = {"x":-CX, "y":-CY}
mouse = (CX, CY + 100)
dx = "pas bouger"
dy = "pas bouger"
transformations = [
    "basic tank",
    "twin",
    "triple shot",
    "quad tank",
    "twin flank guard",
    "tri flank guard",
    "octogones",
    "penta shot"
    
]
transformation = 5
# transformation = transformations[0]
monde = (2000, 2000)

squares = []
pentagons = []
triangle = []
score = 0
boulets = []
ultimepentagons = []

zelda = pygame.image.load(os.path.join("img", "zelda.png"))
zeldah = zelda.get_height()/4
zeldaw = zelda.get_width()/5
zeldap = 0.
zeldadp = 1.
zeldav = 0.1

for i in range(0,40):
    squares.append((random.random()*monde[0]-monde[0]/2, random.random()*monde[1]-monde[1]/2))
for i in range(0,30):
    triangle.append((random.random()*monde[0]-monde[0]/2, random.random()*monde[1]-monde[1]/2))
for i in range(0,30):
    pentagons.append((random.random()*monde[0]-monde[0]/2, random.random()*monde[1]-monde[1]/2))
for i in range(1,):
    ultimepentagons.append((random.random()*monde[0]-monde[0]/2, random.random()*monde[1]-monde[1]/2))

def rotate(center, point, angle):
    cx, cy = center[0], center[1]
    x, y = point[0], point[1]
    cosx, sinx = math.cos(angle), math.sin(angle)
    x, y = x - cx, y - cy
    return (
        int(x * cosx - y * sinx + cx),
        int(x * sinx + y * cosx + cy)
    )

def rotate_rect(center, points, angle):
    res = []
    for p in points:
        res.append(rotate(center, p, angle))
    return res

def angle(a, b):
    x1, y1 = a[0], a[1]
    x2, y2 = b[0], b[1]
    return math.atan2(y2-y1, x2-x1)
    
def afficheMoi():
    global position
    x, y = CX, CY
    a = angle((x,y), mouse) - math.pi / 2
    l = 3
    rect = [(x-5, y), (x+5, y), (x+5, y+40), (x-5, y+40)]
    rect2 = [(x-5-l, y), (x+5+l, y), (x+5+l, y+40+l), (x-5-l, y+40+l)]
    canon = rotate_rect((x,y), rect, a)
    canon2 = rotate_rect((x,y), rect2, a)
   
    if transformation == 0: #"basic tank":

        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon, (180,183,187))
        
    elif transformation == 1: #"twin tank":
        
        l = 3
        rect = [(x-10, y), (x+10, y), (x+10, y+40), (x-10, y+40)]
        rect2 = [(x-10-l, y), (x+10+l, y), (x+10+l, y+40+l), (x-10-l, y+40+l)]
        line = [(x,y),(x,y+40)]
        canon = rotate_rect((x,y), rect, a)
        canon2 = rotate_rect((x,y), rect2, a) 
        c = rotate_rect((x,y), line, a)
        
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.line(DISPLAYSURF, c[0][0],c[0][1],c[1][0],c[1][1], (60,60,180))
    
    elif transformation == 2:
        
        l = 3
        rect = [(x-5, y), (x+5, y), (x+5, y+40), (x-5, y+40)]
        rect2 = [(x-5-l, y), (x+5+l, y), (x+5+l, y+40+l), (x-5-l, y+40+l)]
        canon = rotate_rect((x,y), rect, a)
        canon2 = rotate_rect((x,y), rect2, a)
        
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon, (180,183,187))
        
        canon = rotate_rect((x,y), rect, a + math.pi / 4)
        canon2 = rotate_rect((x,y), rect2, a + math.pi / 4)
        
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon, (180,183,187))
        
        canon = rotate_rect((x,y), rect, a - math.pi / 4)
        canon2 = rotate_rect((x,y), rect2, a - math.pi / 4)
        
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon, (180,183,187))
        
    elif transformation == 3:
        
        l = 3
        rect = [(x-5, y), (x+5, y), (x+5, y+40), (x-5, y+40)]
        rect2 = [(x-5-l, y), (x+5+l, y), (x+5+l, y+40+l), (x-5-l, y+40+l)]
        canon = rotate_rect((x,y), rect, a)
        canon2 = rotate_rect((x,y), rect2, a)
        
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon, (180,183,187))
        
        canon = rotate_rect((x,y), rect, a + math.pi / 2)
        canon2 = rotate_rect((x,y), rect2, a + math.pi / 2)
                    
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon, (180,183,187))
        
        canon = rotate_rect((x,y), rect, a - math.pi / 2)
        canon2 = rotate_rect((x,y), rect2, a - math.pi / 2)
        
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon, (180,183,187))   
           
        canon = rotate_rect((x,y), rect, a - math.pi)
        canon2 = rotate_rect((x,y), rect2, a - math.pi)
        
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon, (180,183,187))
    
    elif transformation == 4:
    
        l = 3
        rect = [(x-10, y), (x+10, y), (x+10, y+40), (x-10, y+40)]
        rect2 = [(x-10-l, y), (x+10+l, y), (x+10+l, y+40+l), (x-10-l, y+40+l)]
        line = [(x,y),(x,y+40)]
        canon = rotate_rect((x,y), rect, a)
        canon2 = rotate_rect((x,y), rect2, a) 
        c = rotate_rect((x,y), line, a)
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.line(DISPLAYSURF, c[0][0],c[0][1],c[1][0],c[1][1], (60,60,180))
        l = 3
        rect = [(x-10, y), (x+10, y), (x+10, y-40), (x-10, y-40)]
        rect2 = [(x-10-l, y), (x+10+l, y), (x+10+l, y-40-l), (x-10-l, y-40-l)]
        line = [(x,y),(x,y-40)]
        canon = rotate_rect((x,y), rect, a)
        canon2 = rotate_rect((x,y), rect2, a) 
        c = rotate_rect((x,y), line, a)
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.line(DISPLAYSURF, c[0][0],c[0][1],c[1][0],c[1][1], (60,60,180))
        
    elif transformation == 5:
        
        l = 3
        rect = [(x-10, y), (x+10, y), (x+10, y+40), (x-10, y+40)]
        rect2 = [(x-10-l, y), (x+10+l, y), (x+10+l, y+40+l), (x-10-l, y+40+l)]
        line = [(x,y),(x,y+40)]
        canon = rotate_rect((x,y), rect, a)
        canon2 = rotate_rect((x,y), rect2, a) 
        c = rotate_rect((x,y), line, a)
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.line(DISPLAYSURF, c[0][0],c[0][1],c[1][0],c[1][1], (60,60,180))
        l = 3
        rect = [(x-10, y), (x+10, y), (x+10, y+40), (x-10, y+40)]
        rect2 = [(x-10-l, y), (x+10+l, y), (x+10+l, y+40+l), (x-10-l, y+40+l)]
        line = [(x,y),(x,y+40)]
        canon = rotate_rect((x,y), rect, a + math.pi * 4 / 3)
        canon2 = rotate_rect((x,y), rect2, a + math.pi * 4 / 3) 
        c = rotate_rect((x,y), line, a + math.pi * 4 / 3)
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.line(DISPLAYSURF, c[0][0],c[0][1],c[1][0],c[1][1], (60,60,180))
        l = 3
        rect = [(x-10, y), (x+10, y), (x+10, y+40), (x-10, y+40)]
        rect2 = [(x-10-l, y), (x+10+l, y), (x+10+l, y+40+l), (x-10-l, y+40+l)]
        line = [(x,y),(x,y+40)]
        canon = rotate_rect((x,y), rect, a+ math.pi * 2 / 3)
        canon2 = rotate_rect((x,y), rect2, a + math.pi * 2 / 3) 
        c = rotate_rect((x,y), line, a+ math.pi * 2 / 3)
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon2, (60,60,180))
        pygame.gfxdraw.filled_polygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.aapolygon(DISPLAYSURF, canon, (180,183,187))
        pygame.gfxdraw.line(DISPLAYSURF, c[0][0],c[0][1],c[1][0],c[1][1], (60,60,180))

    pygame.gfxdraw.filled_circle(DISPLAYSURF, x,y, 22, (60,60,180))
    pygame.gfxdraw.aacircle(DISPLAYSURF, x,y, 22, (60,60,180))
    pygame.gfxdraw.filled_circle(DISPLAYSURF, x,y, 18, (124,176,253))
    pygame.gfxdraw.aacircle(DISPLAYSURF, x,y, 18, (124,176,253))

        
def afficheMonde():
    l, h = monde[0], monde[1]
    x = position["x"]
    y = position["y"]
    pygame.draw.rect(DISPLAYSURF, (150,200,100), pygame.Rect(int(-l/2)-x-500, -int(h/2)-y-500, l+1000, h+1000))
    pygame.draw.rect(DISPLAYSURF, (180,220,120), pygame.Rect(int(-l/2)-x, -int(h/2)-y, l, h))
    for i in range(int(-l/2), int(l/2)+1, 50):
        pygame.draw.line(DISPLAYSURF, (255,255,255), (i-x, int(-h/2)-y), (i-x, int(h/2)-y))
    for j in range(int(-h/2), int(h/2)+1, 50):
        pygame.draw.line(DISPLAYSURF, (255,255,255), (int(-l/2)-x, j-y), (int(l/2)-x, j-y))

def afficheObstacle():
    x = position["x"]
    y = position["y"]
    for i in squares:
        pygame.draw.rect(DISPLAYSURF, (210,50,50), pygame.Rect(i[0]-x, i[1]-y, 20, 20))

def afficheObstacle2():
    x = position["x"]
    y = position["y"]
    for i in triangle:
        pygame.draw.polygon(DISPLAYSURF,(0,0,210), [(i[0]-x, i[1]-y), (i[0]-10-x, i[1]+20-y), (i[0]+10-x, i[1]+20-y)])

def afficheObstacle3():
    x = position["x"]
    y = position["y"]
    for i in pentagons:
        a = i[0]-x
        b = i[1]-y
        points = [(a,b-20),(a-20,b-10),(a-16,b+16),(a+16,b+16),(a+20,b-10)]
        pygame.draw.polygon(DISPLAYSURF,(0,210,0),points)
        
def afficheObstacle4():
    x = position["x"]
    y = position["y"]
    for i in ultimepentagons:
        a = i[0]-x
        b = i[1]-y
        points = [(a,b-2),(a-2,b-1),(a-2,b+2),(a+2,b+2),(a+2,b-1)]
        pygame.draw.polygon(DISPLAYSURF,(0,210,0),points)
    
def afficheBoulets():
    x = position["x"]
    y = position["y"]
    for b in boulets:
        pygame.draw.circle(DISPLAYSURF, (50,50,253), (int(b[0]-x),int(b[1]-y)), 7)

def afficheScore():
    scoreSurf = BASICFONT.render('Score: %s' % (score), True, (250,250,250))
    scoreRect = scoreSurf.get_rect()
    scoreRect.topleft = (20, 20)
    DISPLAYSURF.blit(scoreSurf, scoreRect)

    scoreSurf = BASICFONT.render(transformations[transformation], True, (250,250,250))
    scoreRect = scoreSurf.get_rect()
    scoreRect.topleft = (20, 80)
    DISPLAYSURF.blit(scoreSurf, scoreRect)

def afficheLevel():
    return

def afficheZelda():
    global zeldap, zeldadp
    DISPLAYSURF.blit(zelda, (100,100), ((int(zeldap)*zeldaw, 0), (zeldaw, zeldah)))
    if zeldap <= 0:
        zeldadp = 1
    elif zeldap >= 4:
        zeldadp = -1
    zeldap = zeldap+zeldadp*zeldav
    
def collisions():
    global score
    x = position["x"]
    y = position["y"]
    for i in squares:
        for j in boulets:
            if pygame.Rect(i[0]-x, i[1]-y, 20, 20).colliderect(pygame.Rect(j[0]-7-x, j[1]-7-y, 14, 14)):
                if i in squares:
                    squares.remove(i)
                squares.append((random.random()*monde[0]-monde[0]/2, random.random()*monde[1]-monde[1]/2))
                score = score + 1
                
    for i in pentagons:
        for j in boulets:
            if pygame.Rect(i[0]-10-x, i[1]-10-y, 20, 20).colliderect(pygame.Rect(j[0]-7-x, j[1]-7-y, 14, 14)):
                if i in pentagons:
                    pentagons.remove(i)
                pentagons.append((random.random()*monde[0]-monde[0]/2, random.random()*monde[1]-monde[1]/2))
                score = score + 5
                
    for i in triangle:
        for j in boulets:
            if pygame.Rect(i[0]-10-x, i[1]-10-y, 20, 20).colliderect(pygame.Rect(j[0]-7-x, j[1]-7-y, 14, 14)):
                if i in triangle:
                    triangle.remove(i)
                triangle.append((random.random()*monde[0]-monde[0]/2, random.random()*monde[1]-monde[1]/2))
                score = score + 3
                
    for i in ultimepentagons:
        for j in boulets:
            if pygame.Rect(i[0]-10-x, i[1]-10-y, 20, 20).colliderect(pygame.Rect(j[0]-7-x, j[1]-7-y, 14, 14)):
                if i in ultimepentagons:
                    ultimepentagons.remove(i)
                ultimepentagons.append((random.random()*monde[0]-monde[0]/2, random.random()*monde[1]-monde[1]/2))
                score = score + 100   
        
def terminate():
    pygame.quit()
    sys.exit()
    
while True:
    
    canon = "nepastirer"    
    # Evenements
    for event in pygame.event.get(): # event handling loop
        if event.type == QUIT:
            terminate()
        elif event.type == KEYDOWN:
            if (event.key == K_LEFT or event.key == K_a) :
                dx = "gauche"
            elif (event.key == K_RIGHT or event.key == K_d):
                dx = "droite"
            elif (event.key == K_UP or event.key == K_w):
                dy = "haut"
            elif (event.key == K_DOWN or event.key == K_s):
                dy = "bas"
            elif (event.key == K_SPACE):
                canon = "tirer"
        elif event.type == KEYUP:
            if (event.key not in (K_LEFT, K_RIGHT, K_UP, K_DOWN)):
                continue
            elif (event.key == K_LEFT or dx == "gauche") :
                dx = "pas bouger"
            elif (event.key == K_RIGHT or dx == "droite"):
                dx = "pas bouger"
            elif (event.key == K_UP or dy == "haut"):
                dy = "pas bouger"
            elif (event.key == K_DOWN or dy == "bas"):
                dy = "pas bouger"
        elif event.type == MOUSEBUTTONDOWN:
            canon = "tirer"

    mouse = pygame.mouse.get_pos()
    if score > 99 and transformation == 0:
        position = {"x":-CX, "y":-CY}
        transformation = transformation+1
    elif score > 999 and transformation == 1:
        position = {"x":-CX, "y":-CY}
        transformation = transformation+1
    elif score > 1999 and transformation == 2:
        position = {"x":-CX, "y":-CY}
        transformation = transformation+1
    elif score > 4999 and transformation == 3:
        position = {"x":-CX, "y":-CY}
        transformation = transformation+1
    elif score > 7999 and transformation == 4:
        position = {"x":-CX, "y":-CY}
        transformation = transformation+1
    elif score > 9999 and transformation == 5:
        position = {"x":-CX, "y":-CY}
        transformation = transformation+1
    elif score > 19999 and transformation == 6:
        position = {"x":-CX, "y":-CY}
        transformation = transformation+1
    elif score > 29999 and transformation == 7:
        position = {"x":-CX, "y":-CY}
        transformation = transformation+1
        
    # Calculs
    x, y = position["x"], position["y"]
    if canon == "tirer":
        if transformation == 0:
            boulets.append([CX+x,CY+y, angle((CX,CY), mouse), 100])
        elif transformation == 1:
            points = [(CX+x,CY+10+y), (CX+x,CY-10+y)]
            a = angle((CX,CY), mouse)
            p = rotate_rect((CX+x,CY+y), points, a)
            boulets.append([p[0][0],p[0][1], a, 100])
            boulets.append([p[1][0],p[1][1], a, 100])
        elif transformation == 2:
            boulets.append([CX+x,CY+y, angle((CX,CY), mouse), 100])
            boulets.append([CX+x,CY+y, angle((CX,CY), mouse) + math.pi / 4, 100])
            boulets.append([CX+x,CY+y, angle((CX,CY), mouse) - math.pi / 4, 100])
        elif transformation == 3:
            boulets.append([CX+x,CY+y, angle((CX,CY), mouse), 100])
            boulets.append([CX+x,CY+y, angle((CX,CY), mouse) + math.pi / 2, 100])
            boulets.append([CX+x,CY+y, angle((CX,CY), mouse) - math.pi / 2, 100])
            boulets.append([CX+x,CY+y, angle((CX,CY), mouse) - math.pi, 100])
        elif transformation == 4:
            points = [(CX+x,CY+10+y), (CX+x,CY-10+y)]
            a = angle((CX,CY), mouse)
            p = rotate_rect((CX+x,CY+y), points, a)
            boulets.append([p[0][0],p[0][1], a, 100])
            boulets.append([p[1][0],p[1][1], a, 100])
            points = [(CX+x,CY+10+y), (CX+x,CY-10+y)]
            a = angle((CX,CY), mouse)
            p = rotate_rect((CX+x,CY+y), points, a + math.pi)
            boulets.append([p[0][0],p[0][1], a + math.pi, 100])
            boulets.append([p[1][0],p[1][1], a + math.pi, 100])
        elif transformation == 5:
            points = [(CX+x,CY+10+y), (CX+x,CY-10+y)]
            a = angle((CX,CY), mouse)
            p = rotate_rect((CX+x,CY+y), points, a)
            boulets.append([p[0][0],p[0][1], a, 100])
            boulets.append([p[1][0],p[1][1], a, 100])
            points = [(CX+x,CY+10+y), (CX+x,CY-10+y)]
            a = angle((CX,CY), mouse)
            p = rotate_rect((CX+x,CY+y), points, a + math.pi * 4 / 3)
            boulets.append([p[0][0],p[0][1], a + math.pi * 4 / 3, 100])
            boulets.append([p[1][0],p[1][1], a + math.pi * 4 / 3, 100])
            points = [(CX+x,CY+10+y), (CX+x,CY-10+y)]
            a = angle((CX,CY), mouse)
            p = rotate_rect((CX+x,CY+y), points, a + math.pi * 2 / 3  )
            boulets.append([p[0][0],p[0][1], a + math.pi * 2 / 3, 100])
            boulets.append([p[1][0],p[1][1], a + math.pi * 2 / 3, 100])
            
    # Nouvelles position
    vitesse = 2
    if score > 400 and vitesse == 2:
        vitesse = 4
        
    if dx == "gauche":
        position["x"] = x - vitesse
    if dx == "droite":
        position["x"] = x + vitesse
    if dy == "haut":
        position["y"] = y - vitesse
    if dy == "bas":
        position["y"] = y + vitesse
    newb = []        
    for b in boulets:
        b[0] = b[0] + 5 * math.cos(b[2])
        b[1] = b[1] + 5 * math.sin(b[2])
        b[3] = b[3] - 1
        if b[3] > 0:
            newb.append(b)
    boulets = newb
    
    # Collision
    collisions()                                                                                                                                                                                       
                                                                                                                                                      
    # Dessiner:
    DISPLAYSURF.fill((255,255,4))
    
    afficheMonde()
    afficheObstacle()
    afficheObstacle2()
    afficheObstacle3()
    afficheObstacle4()
    afficheBoulets()
    afficheMoi()

    afficheScore()
    afficheLevel()
#     afficheZelda()
    
    pygame.display.update()
    
    FPSCLOCK.tick(60)
# Out:
# pygame 2.0.0 (SDL 2.0.12, python 3.7.4)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Homeware\Miniconda3\lib\site-packages\IPython\core\interactiveshell.py:3339: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
 math.pi / 3
